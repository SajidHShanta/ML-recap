# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# # How Seaborn updates Matplotlib

# %% [markdown]
# ## Seaborn
#     1. Updates matplotlib's rc (run commands) parameters to improve aesthetics

# %%
x = [10, 20, 30, 40]
y = [0, 15, 10, 25]

# %%
plt.title('x-y graph')
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x,y); # uses Matplotlib to plot

# %%
print(plt.style.available) #print available styles for Matplotlib
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('fivethirtyeight') #set the style, sir recomand useing 'fivethirtyeight' or 'ggplot'
plt.title('x-y graph')
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x,y);

# %%
# sns.set()
sns.set(style = 'whitegrid')

# %%
plt.plot(x,y);

# %% [markdown]
# # Kernal Density Estimation (KDE) Plot

# %% [markdown]
# main purpose of KDE:  It uses the datasets (data points) to estimate what kind of distribution it has.
#
# (details on lecture video from 17 min to 32:20 min)

# %% [markdown]
# ## Univariate KDE plot

# %% [markdown]
# Univariate means one veriable

# %%
print(sns.get_dataset_names()) #get a list of datasets name, which are auto downloaded with Anaconda
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'taxis', 'tips', 'titanic']

# %%
cars = sns.load_dataset('mpg') # cars here is the pandas dataframe
cars.shape #return total (row, column) numbers of dataframe
# Out:
# (398, 9)

# %%
cars = cars.dropna() #drop null rows
#cars.dropna(inplace = True) #we can also drop with this comand, insted of agerta
cars.shape
# Out:
# (392, 9)

# %%
cars.head(10)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
# 5  15.0          8         429.0       198.0    4341          10.0
# 6  14.0          8         454.0       220.0    4354           9.0
# 7  14.0          8         440.0       215.0    4312           8.5
# 8  14.0          8         455.0       225.0    4425          10.0
# 9  15.0          8         390.0       190.0    3850           8.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# ...

# %%
cars['cylinders'].value_counts()
# Out:
# 4    199
# 8    103
# 6     83
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
sns.kdeplot(x = 'horsepower', data = cars); #plot the density of horsepower

# %%
cars['horsepower'].describe() # Summary statistics of horsepower
# Out:
# count    392.000000
# mean     104.469388
# std       38.491160
# min       46.000000
# 25%       75.000000
# 50%       93.500000
# 75%      126.000000
# max      230.000000
# Name: horsepower, dtype: float64

# %%
sns.kdeplot(x = 'horsepower', data = cars, shade = True, color = 'black');

# %%
sns.kdeplot(y = 'horsepower', data = cars, shade = True); #use y axis, instead of x

# %%
sns.kdeplot(x = 'horsepower', data = cars, cumulative = True); #cumulative distribution

# %%
sns.kdeplot(x = 'horsepower', data = cars, cumulative = True, color = 'red');  #we can change color

# %%
print(cars.columns)
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %% [markdown]
# Scatterplot only plot the data points

# %%
sns.scatterplot(x = 'horsepower', y = 'mpg', data = cars );

# %% [markdown]
# # Bivariate KDE plot

# %% [markdown]
# Bivariate means 2 veriable

# %%
sns.kdeplot(x = 'horsepower', y = 'mpg', data = cars);

# %%
sns.kdeplot(x = 'horsepower', y = 'mpg', data = cars, cumulative = True);

# %%
cars = cars[cars.cylinders.isin([4,8])] #if the cylinders value is 4 and 8
sns.kdeplot(x = 'horsepower', y = 'mpg', hue = 'cylinders', data = cars ); #hue will be always Cetagorical value

# %%
sns.kdeplot(x = 'horsepower', y = 'mpg', hue = 'cylinders', data = cars, palette = 'PiYG' ); #use Palette for coler palette

# %% [markdown]
# # Histplot

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'tips', 'titanic']

# %%
penguins = sns.load_dataset('penguins') # penguins is the panda's dataframe, 'penguins' is the dataset

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins.shape
# Out:
# (344, 7)

# %%
penguins.dropna(inplace = True)
penguins.shape
# Out:
# (333, 7)

# %%
penguins['species'].value_counts()
# Out:
# Adelie       146
# Gentoo       119
# Chinstrap     68
# Name: species, dtype: int64

# %%
penguins['island'].value_counts()
# Out:
# Biscoe       163
# Dream        123
# Torgersen     47
# Name: island, dtype: int64

# %%
sns.set_style('darkgrid')

# %%
penguins.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
sns.histplot(x = 'bill_length_mm', data = penguins);

# %%
sns.histplot(y = 'bill_length_mm', data = penguins);

# %%
sns.histplot(x = 'bill_length_mm', kde = True, data = penguins);

# %%
sns.histplot(x = 'bill_length_mm', bins = 50, data = penguins);

# %%
sns.histplot(x = 'bill_length_mm', binwidth = 2, binrange = (30, 45), data = penguins);

# %%
sns.histplot(x = 'bill_length_mm', data = penguins, stat = 'count');

# %%
sns.histplot(x = 'bill_length_mm', data = penguins, stat = 'density'); # Area of the histogram should sum to 1

# %%
sns.histplot(x = 'bill_length_mm', data = penguins, stat = 'probability'); # Heights should sum to 1

# %%
sns.histplot(x = 'bill_length_mm', data = penguins, stat = 'frequency');

# %%
sns.histplot(x = 'bill_length_mm', data = penguins, stat = 'probability', fill = False);

# %%
sns.histplot(x = 'bill_length_mm', data = penguins, stat = 'probability', element = 'step', fill = False);

# %%
sns.histplot(x = 'bill_length_mm', data = penguins, stat = 'probability', element = 'step', fill = False, cumulative = True);

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 4       3450.0  Female
# 5       3650.0    Male

# %%
sns.histplot(x = 'bill_length_mm', data = penguins, hue = 'species'); #hue must be a categorical variable

# %%
sns.histplot(x = 'bill_length_mm', data = penguins, hue = 'island'); #hue must be a categorical variable

# %%
sns.histplot(x = 'bill_length_mm', data = penguins, hue = 'species', element = 'step'); #hue must be a categorical variable

# %%
sns.histplot(x = 'bill_length_mm', data = penguins, hue = 'species', multiple = 'layer'); #hue must be a categorical variable

# %%
sns.histplot(x = 'bill_length_mm', data = penguins, hue = 'species', multiple = 'stack');

# %%
sns.histplot(x = 'bill_length_mm', data = penguins, hue = 'species', multiple = 'fill');

# %% [markdown]
# # Bivariate Histplot

# %%
sns.set_style('white')

# %%
penguins.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
sns.histplot(x = 'bill_length_mm', y = 'bill_depth_mm', data = penguins, cbar = True);

# %% [markdown]
# # ECDF plot

# %% [markdown]
# ## - Empirical Cumulative Distribution Functions.
#
# seaborn.ecdfplot(data=None, *, x=None, y=None, hue=None, weights=None, stat='proportion', complementary=False, palette=None, hue_order=None, hue_norm=None, log_scale=None, legend=True, ax=None, **kwargs)
#
# An ECDF represents the proportion or count of observations falling below each unique value in a dataset. Compared to a histogram or density plot, it has the advantage that each observation is visualized directly, meaning that there are no binning or smoothing parameters that need to be adjusted. It also aids direct comparisons between multiple distributions. A downside is that the relationship between the appearance of the plot and the basic properties of the distribution (such as its central tendency, variance, and the presence of any bimodality) may not be as intuitive.

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'tips', 'titanic']

# %%
tips = sns.load_dataset('tips') # tips here is the dataframe

# %%
print(tips.shape)
tips.head()
# Out:
# (244, 7)
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.ecdfplot(x = 'tip', data = tips);

# %%
sns.ecdfplot(x = 'tip', data = tips)
plt.axvline(4, c = 'black');

# %%
sns.ecdfplot(y = 'tip', data = tips);

# %%
sns.ecdfplot(x = 'tip', data = tips, hue = 'time'); # What can you interpret?

# %%
sns.ecdfplot(x = 'tip', data = tips, hue = 'time', stat = 'count');

# %%
sns.ecdfplot(x = 'tip', data = tips, hue = 'sex'); # What is the interpretation?

# %%
sns.ecdfplot(x = 'tip', data = tips, hue = 'smoker'); # What is the interpretation?

# %%
sns.ecdfplot(x = 'tip', data = tips, hue = 'day'); # What is the interpretation?

# %%
sns.ecdfplot(x = 'tip', data = tips, hue = 'day', palette = 'summer');

# %%
sns.set()
p = sns.ecdfplot(x = 'tip', data = tips, hue = 'day')
p.legend(['Thursday', 'Friday', 'Saturday', 'Sunday'], title = 'Day of the Week');

# %% [markdown]
# # Boxplot

# %% [markdown]
# ## seaborn.boxplot(*, x=None, y=None, hue=None, data=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, width=0.8, dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None, **kwargs)
#
# A box plot (or box-and-whisker plot) shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable. The box shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution, except for points that are determined to be “outliers” using a method that is a function of the inter-quartile range.

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.boxplot(x = 'tip', data = tips);

# %%
tips['tip'].describe()
# Out:
# count    244.000000
# mean       2.998279
# std        1.383638
# min        1.000000
# 25%        2.000000
# 50%        2.900000
# 75%        3.562500
# max       10.000000
# Name: tip, dtype: float64

# %%
sns.boxplot(y = 'tip', x = 'sex', data = tips);

# %%
sns.boxplot(y = 'tip', x = 'day', data = tips);

# %%
sns.boxplot(y = 'tip', x = 'day', hue = 'sex', data = tips);

# %%
sns.boxplot(y = 'tip', x = 'day', hue = 'smoker', data = tips);

# %%
sns.boxplot(y = 'tip', x = 'day', hue = 'smoker', data = tips, order = ['Sun', 'Thur', 'Fri', 'Sat']);

# %%
sns.boxplot(y = 'tip', x = 'day', hue = 'smoker', data = tips, order = ['Sun', 'Thur', 'Fri', 'Sat'], hue_order = ['No', 'Yes']);

# %%
sns.boxplot(y = 'tip', x = 'time', data = tips);

# %%
sns.boxplot(x = 'tip', y = 'time', data = tips);

# %%
sns.boxplot(x = 'tip', y = 'time', data = tips, color = '#9999ff');

# %%
sns.boxplot(x = 'tip', y = 'time', data = tips, color = 'red', hue = 'smoker');

# %%
sns.boxplot(x = 'tip', y = 'time', data = tips, color = 'red', hue = 'smoker', width = 0.5, linewidth = 2.5);

# %%
sns.boxplot(x = 'tip', y = 'time', data = tips, color = 'red', hue = 'smoker', whis = 3);

# %%
sns.boxplot(x = 'tip', y = 'time', data = tips, color = 'red', hue = 'smoker', whis = 3, fliersize = 9);

# %% [markdown]
# # Swarmplot

# %% [markdown]
# ## seaborn.swarmplot(*, x=None, y=None, hue=None, data=None, order=None, hue_order=None, dodge=False, orient=None, color=None, palette=None, size=5, edgecolor='gray', linewidth=0, ax=None, **kwargs)
#
# This function is similar to stripplot(), but the points are adjusted (only along the categorical axis) so that they don’t overlap. This gives a better representation of the distribution of values, but it does not scale well to large numbers of observations. This style of plot is sometimes called a “beeswarm”.

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.set_style('whitegrid')

# %%
sns.swarmplot(x = 'tip', data = tips);

# %%
sns.swarmplot(x = 'sex', y = 'tip', data = tips);

# %%
sns.swarmplot(x = 'sex', y = 'tip', data = tips, hue = 'smoker');

# %%
sns.swarmplot(x = 'sex', y = 'tip', data = tips, hue = 'smoker', dodge = True);

# %% [markdown]
# ## Overlaying on the top of the boxplot

# %%
sns.boxplot(x = 'sex', y = 'tip', data = tips, hue = 'smoker', dodge = True);
sns.swarmplot(x = 'sex', y = 'tip', data = tips, hue = 'smoker', dodge = True);

# %%
sns.boxplot(x = 'sex', y = 'tip', data = tips, hue = 'smoker', dodge = True);
sns.swarmplot(x = 'sex', y = 'tip', data = tips, hue = 'smoker', dodge = True, color = 'black');

# %%
sns.boxplot(x = 'sex', y = 'tip', data = tips, hue = 'smoker', dodge = True);
sns.swarmplot(x = 'sex', y = 'tip', data = tips, hue = 'smoker', dodge = True, color = 'black', alpha = 0.5);
